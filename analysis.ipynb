# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
segments = pd.read_hdf('preproc_segments.h5', 'segments')
segments.head(2)
# Out:
#    time        dist  climb   ride_dist  ride_climb  altitude     speed  \
# 0  57.0  227.154648   -2.0    0.000000         0.0       8.0  3.985169
# 1  55.0  268.542450    1.0  294.923096         0.0       6.0  4.882590
#
#    dist_remaining  gradient
# 0   121579.171875 -0.880457
# 1   121284.250000  0.372381

# %%
sns.relplot(data=segments, x='dist_remaining', y='speed', s=5)

# %%
ax = sns.relplot(data=segments, x='gradient', y='speed', s=10)
ax.set(xlim=(-15,15), ylim=(0, 30))

# %%
ax = sns.relplot(data=segments, x='altitude', y='speed', s=10)
# ax.set(xlim=(-15,15), ylim=(0, 30))

# %%
# Climbing speeds. Investigate effect of altitude. For a given gradient, does the increase in altitude matter matter
fltr = segments['gradient'] > 5
subset = segments.loc[fltr]
plt.scatter(subset['altitude'], subset['speed'] / subset['gradient'])
